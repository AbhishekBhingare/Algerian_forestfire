# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE (1).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 247 entries, ('day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI') to ('30', '09', '2012', '24', '64', '15', '0.2', '67.3', '3.8', '16.5', '1.2', '4.8', '0.5')
# Data columns (total 1 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Bejaia Region Dataset   245 non-null    object
# dtypes: object(1)
# memory usage: 49.3+ KB

# %%
df.head()
# Out:
#                                                                   Bejaia Region Dataset
# day month year Temperature  RH  Ws Rain  FFMC DMC DC  ISI BUI FWI              Classes
# 01  06    2012 29          57  18  0     65.7 3.4 7.6 1.3 3.4 0.5            not fire
# 02  06    2012 29          61  13  1.3   64.4 4.1 7.6 1   3.9 0.4            not fire
# 03  06    2012 26          82  22  13.1  47.1 2.5 7.1 0.3 2.7 0.1            not fire
# 04  06    2012 25          89  13  2.5   28.6 1.3 6.9 0   1.7 0              not fire

# %%
df.columns
# Out:
# Index(['Bejaia Region Dataset '], dtype='object')

# %%
df.head(2)
# Out:
#                                                                   Bejaia Region Dataset
# day month year Temperature  RH  Ws Rain  FFMC DMC DC  ISI BUI FWI              Classes
# 01  06    2012 29          57  18  0     65.7 3.4 7.6 1.3 3.4 0.5            not fire

# %%
df = df.reset_index()

# %%
df
# Out:
#     level_0 level_1 level_2      level_3 level_4 level_5 level_6 level_7  \
# 0       day   month    year  Temperature      RH      Ws   Rain     FFMC
# 1        01      06    2012           29      57      18       0    65.7
# 2        02      06    2012           29      61      13     1.3    64.4
# 3        03      06    2012           26      82      22    13.1    47.1
# 4        04      06    2012           25      89      13     2.5    28.6
# ..      ...     ...     ...          ...     ...     ...     ...     ...
# 242      26      09    2012           30      65      14       0    85.4
# 243      27      09    2012           28      87      15     4.4    41.1
# 244      28      09    2012           27      87      29     0.5    45.9
# 245      29      09    2012           24      54      18     0.1    79.7
# 246      30      09    2012           24      64      15     0.2    67.3
#
#     level_8 level_9 level_10 level_11 level_12 Bejaia Region Dataset
# ...

# %%
df.columns
# Out:
# Index(['level_0', 'level_1', 'level_2', 'level_3', 'level_4', 'level_5',
#        'level_6', 'level_7', 'level_8', 'level_9', 'level_10', 'level_11',
#        'level_12', 'Bejaia Region Dataset '],
#       dtype='object')

# %%
df['day'] = df['level_0']

# %%
df['month']=df['level_1']

# %%
df.head()
# Out:
#   level_0 level_1 level_2      level_3 level_4 level_5 level_6 level_7  \
# 0     day   month    year  Temperature      RH      Ws   Rain     FFMC
# 1      01      06    2012           29      57      18       0    65.7
# 2      02      06    2012           29      61      13     1.3    64.4
# 3      03      06    2012           26      82      22    13.1    47.1
# 4      04      06    2012           25      89      13     2.5    28.6
#
#   level_8 level_9 level_10 level_11 level_12 Bejaia Region Dataset   day  \
# 0     DMC      DC      ISI      BUI      FWI              Classes    day
# 1     3.4     7.6      1.3      3.4      0.5            not fire      01
# 2     4.1     7.6        1      3.9      0.4            not fire      02
# 3     2.5     7.1      0.3      2.7      0.1            not fire      03
# 4     1.3     6.9        0      1.7        0            not fire      04
#
#    month
# 0  month
# 1     06
# 2     06
# 3     06
# 4     06

# %%
df.columns
# Out:
# Index(['level_0', 'level_1', 'level_2', 'level_3', 'level_4', 'level_5',
#        'level_6', 'level_7', 'level_8', 'level_9', 'level_10', 'level_11',
#        'level_12', 'Bejaia Region Dataset ', 'day', 'month'],
#       dtype='object')

# %%
columns_drop = ['level_2','level_3','level_4','level_5','level_6','level_7','level_8','level_9','level_10','level_11','level_12','Bejaia Region Dataset ']

# %%
df['year']=df['level_2']
df['Temperature'] = df['level_3']
df['RH'] = df['level_4']
df['Ws'] = df['level_5']
df['Rain'] = df['level_6']
df['FFMC'] = df['level_7']
df['DMC'] = df['level_8']
df['DC'] = df['level_9']
df['ISI'] = df['level_10']
df['BUI'] = df['level_11']
df['FWI	'] = df['level_12']
df['Classes'] = df['Bejaia Region Dataset ']

# %%
df.head()
# Out:
#   level_0 level_1 level_2      level_3 level_4 level_5 level_6 level_7  \
# 0     day   month    year  Temperature      RH      Ws   Rain     FFMC
# 1      01      06    2012           29      57      18       0    65.7
# 2      02      06    2012           29      61      13     1.3    64.4
# 3      03      06    2012           26      82      22    13.1    47.1
# 4      04      06    2012           25      89      13     2.5    28.6
#
#   level_8 level_9  ...   RH   Ws   Rain  FFMC  DMC   DC  ISI  BUI FWI\t  \
# 0     DMC      DC  ...   RH   Ws  Rain   FFMC  DMC   DC  ISI  BUI   FWI
# 1     3.4     7.6  ...   57   18      0  65.7  3.4  7.6  1.3  3.4   0.5
# 2     4.1     7.6  ...   61   13    1.3  64.4  4.1  7.6    1  3.9   0.4
# 3     2.5     7.1  ...   82   22   13.1  47.1  2.5  7.1  0.3  2.7   0.1
# 4     1.3     6.9  ...   89   13    2.5  28.6  1.3  6.9    0  1.7     0
#
#        Classes
# 0    Classes
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire
#
# ...

# %%
df.drop(columns=columns_drop,inplace=True)

# %%
day	month	year	Temperature	RH	Ws	Rain	FFMC	DMC	DC	ISI	BUI	FWI	Classes
# Out:
#   Cell In[36], line 1
#     day	month	year	Temperature	RH	Ws	Rain	FFMC	DMC	DC	ISI	BUI	FWI	Classes
#        	^
# SyntaxError: invalid syntax

# %%
df.drop(columns=['level_0','level_1'], inplace=True)

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC    DC  ISI  \
# 0    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 1     01     06  2012           29   57   18      0  65.7  3.4   7.6  1.3
# 2     02     06  2012           29   61   13    1.3  64.4  4.1   7.6    1
# 3     03     06  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 4     04     06  2012           25   89   13    2.5  28.6  1.3   6.9    0
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 242   26     09  2012           30   65   14      0  85.4   16  44.5  4.5
# 243   27     09  2012           28   87   15    4.4  41.1  6.5     8  0.1
# 244   28     09  2012           27   87   29    0.5  45.9  3.5   7.9  0.4
# 245   29     09  2012           24   54   18    0.1  79.7  4.3  15.2  1.7
# 246   30     09  2012           24   64   15    0.2  67.3  3.8  16.5  1.2
#
#       BUI FWI\t       Classes
# 0     BUI   FWI     Classes
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI\t', 'Classes'],
#       dtype='object')

# %%
df['FWI']=df['FWI\t']

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC    DC  ISI  \
# 0    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 1     01     06  2012           29   57   18      0  65.7  3.4   7.6  1.3
# 2     02     06  2012           29   61   13    1.3  64.4  4.1   7.6    1
# 3     03     06  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 4     04     06  2012           25   89   13    2.5  28.6  1.3   6.9    0
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 242   26     09  2012           30   65   14      0  85.4   16  44.5  4.5
# 243   27     09  2012           28   87   15    4.4  41.1  6.5     8  0.1
# 244   28     09  2012           27   87   29    0.5  45.9  3.5   7.9  0.4
# 245   29     09  2012           24   54   18    0.1  79.7  4.3  15.2  1.7
# 246   30     09  2012           24   64   15    0.2  67.3  3.8  16.5  1.2
#
#       BUI FWI\t       Classes  FWI
# 0     BUI   FWI     Classes    FWI
# ...

# %%
df.drop(columns='FWI\t', inplace = True)

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC    DC  ISI  \
# 0    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 1     01     06  2012           29   57   18      0  65.7  3.4   7.6  1.3
# 2     02     06  2012           29   61   13    1.3  64.4  4.1   7.6    1
# 3     03     06  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 4     04     06  2012           25   89   13    2.5  28.6  1.3   6.9    0
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 242   26     09  2012           30   65   14      0  85.4   16  44.5  4.5
# 243   27     09  2012           28   87   15    4.4  41.1  6.5     8  0.1
# 244   28     09  2012           27   87   29    0.5  45.9  3.5   7.9  0.4
# 245   29     09  2012           24   54   18    0.1  79.7  4.3  15.2  1.7
# 246   30     09  2012           24   64   15    0.2  67.3  3.8  16.5  1.2
#
#       BUI       Classes  FWI
# 0     BUI     Classes    FWI
# ...

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'Classes', 'FWI'],
#       dtype='object')

# %%
df.iloc[122]
# Out:
# month                   09
# day                     30
# year                  2012
# Temperature             25
# RH                      78
# Ws                      14
# Rain                   1.4
# FFMC                    45
# DMC                    1.9
# DC                     7.5
# ISI                    0.2
# BUI                    2.4
# Classes        not fire
# FWI                    0.1
# Name: 122, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          247 non-null    object
#  1   month        246 non-null    object
#  2   year         246 non-null    object
#  3   Temperature  246 non-null    object
#  4   RH           246 non-null    object
#  5   Ws           246 non-null    object
#  6   Rain         246 non-null    object
#  7   FFMC         246 non-null    object
#  8   DMC          246 non-null    object
#  9   DC           246 non-null    object
#  10  ISI          246 non-null    object
#  11  BUI          246 non-null    object
#  12  Classes      245 non-null    object
#  13  FWI          246 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %%
df.loc[:122,'Region'] = 0
df.loc[122:,'Region'] = 1

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC    DC  ISI  \
# 0    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 1     01     06  2012           29   57   18      0  65.7  3.4   7.6  1.3
# 2     02     06  2012           29   61   13    1.3  64.4  4.1   7.6    1
# 3     03     06  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 4     04     06  2012           25   89   13    2.5  28.6  1.3   6.9    0
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 242   26     09  2012           30   65   14      0  85.4   16  44.5  4.5
# 243   27     09  2012           28   87   15    4.4  41.1  6.5     8  0.1
# 244   28     09  2012           27   87   29    0.5  45.9  3.5   7.9  0.4
# 245   29     09  2012           24   54   18    0.1  79.7  4.3  15.2  1.7
# 246   30     09  2012           24   64   15    0.2  67.3  3.8  16.5  1.2
#
#       BUI       Classes  FWI  Region
# 0     BUI     Classes    FWI     0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          247 non-null    object
#  1   month        246 non-null    object
#  2   year         246 non-null    object
#  3   Temperature  246 non-null    object
#  4   RH           246 non-null    object
#  5   Ws           246 non-null    object
#  6   Rain         246 non-null    object
#  7   FFMC         246 non-null    object
#  8   DMC          246 non-null    object
#  9   DC           246 non-null    object
#  10  ISI          246 non-null    object
#  11  BUI          246 non-null    object
#  12  Classes      245 non-null    object
#  13  FWI          246 non-null    object
#  14  Region       247 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.1+ KB

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
df
# Out:
#      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC    DC  ISI  \
# 0    day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC    DC  ISI
# 1     01     06  2012           29   57   18      0  65.7  3.4   7.6  1.3
# 2     02     06  2012           29   61   13    1.3  64.4  4.1   7.6    1
# 3     03     06  2012           26   82   22   13.1  47.1  2.5   7.1  0.3
# 4     04     06  2012           25   89   13    2.5  28.6  1.3   6.9    0
# ..   ...    ...   ...          ...  ...  ...    ...   ...  ...   ...  ...
# 242   26     09  2012           30   65   14      0  85.4   16  44.5  4.5
# 243   27     09  2012           28   87   15    4.4  41.1  6.5     8  0.1
# 244   28     09  2012           27   87   29    0.5  45.9  3.5   7.9  0.4
# 245   29     09  2012           24   54   18    0.1  79.7  4.3  15.2  1.7
# 246   30     09  2012           24   64   15    0.2  67.3  3.8  16.5  1.2
#
#       BUI       Classes  FWI  Region
# 0     BUI     Classes    FWI       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          247 non-null    object
#  1   month        246 non-null    object
#  2   year         246 non-null    object
#  3   Temperature  246 non-null    object
#  4   RH           246 non-null    object
#  5   Ws           246 non-null    object
#  6   Rain         246 non-null    object
#  7   FFMC         246 non-null    object
#  8   DMC          246 non-null    object
#  9   DC           246 non-null    object
#  10  ISI          246 non-null    object
#  11  BUI          246 non-null    object
#  12  Classes      245 non-null    object
#  13  FWI          246 non-null    object
#  14  Region       247 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 29.1+ KB

# %%
df.isnull().sum()
# Out:
# month          1
# day            0
# year           1
# Temperature    1
# RH             1
# Ws             1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# Classes        2
# FWI            1
# Region         0
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# Out:
# month          0
# day            0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# Classes        0
# FWI            0
# Region         0
# dtype: int64

# %%
df.iloc[[123]]
# Out:
#      month  day  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 124  month  day  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#        Classes  FWI  Region
# 124  Classes    FWI       1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.iloc[[122]].reset_index
# Out:
# <bound method DataFrame.reset_index of      day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#        Classes  FWI  Region
# 122  Classes    FWI       1  >

# %%
df.iloc[[122]]
# Out:
#      month  day  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 122  month  day  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#        Classes  FWI  Region
# 122  Classes    FWI       1

# %%
df=df.drop(122).reset_index(drop=True)

# %%
df.columns
# Out:
# Index(['month', 'day', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'Classes', 'FWI', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4   RH           244 non-null    object
#  5   Ws           244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  Classes      244 non-null    object
#  13  FWI          244 non-null    object
#  14  Region       244 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.7+ KB

# %%
df.head()
# Out:
#    day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC   DC  ISI  BUI  \
# 0  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC   DC  ISI  BUI
# 1   01     06  2012           29   57   18      0  65.7  3.4  7.6  1.3  3.4
# 2   02     06  2012           29   61   13    1.3  64.4  4.1  7.6    1  3.9
# 3   03     06  2012           26   82   22   13.1  47.1  2.5  7.1  0.3  2.7
# 4   04     06  2012           25   89   13    2.5  28.6  1.3  6.9    0  1.7
#
#        Classes  FWI  Region
# 0    Classes    FWI       0
# 1  not fire     0.5       0
# 2  not fire     0.4       0
# 3  not fire     0.1       0
# 4  not fire       0       0

# %%
df[['month','day','year','Temperature','RH','Ws']]= df[['month','day','year','Temperature','RH','Ws']].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df[['month','day','year','Temperature','RH','Ws']]= df[['month','day','year','Temperature','RH','Ws']].astype(int)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
df.iloc[[0]]
# Out:
#    day  month  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  BUI  \
# 0  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      Classes  FWI  Region
# 0  Classes    FWI       0

# %%
df = df.drop(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 df = df.drop(0)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
# ...

# %%
df = df.reset_index()

# %%
df.iloc[[0]]
# Out:
#    index  month  day  year  Temperature   RH   Ws   Rain  FFMC  DMC  DC  ISI  \
# 0      0  month  day  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI
#
#    BUI    Classes  FWI  Region
# 0  BUI  Classes    FWI       0

# %%
##remove the 122nd row
df=df.drop(0).reset_index(drop=True)

# %%
df
# Out:
#      index month day  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  \
# 0        1    06  01  2012          29  57  18     0  65.7  3.4   7.6  1.3
# 1        2    06  02  2012          29  61  13   1.3  64.4  4.1   7.6    1
# 2        3    06  03  2012          26  82  22  13.1  47.1  2.5   7.1  0.3
# 3        4    06  04  2012          25  89  13   2.5  28.6  1.3   6.9    0
# 4        5    06  05  2012          27  77  16     0  64.8    3  14.2  1.2
# ..     ...   ...  ..   ...         ...  ..  ..   ...   ...  ...   ...  ...
# 237    238    09  26  2012          30  65  14     0  85.4   16  44.5  4.5
# 238    239    09  27  2012          28  87  15   4.4  41.1  6.5     8  0.1
# 239    240    09  28  2012          27  87  29   0.5  45.9  3.5   7.9  0.4
# 240    241    09  29  2012          24  54  18   0.1  79.7  4.3  15.2  1.7
# 241    242    09  30  2012          24  64  15   0.2  67.3  3.8  16.5  1.2
#
#       BUI       Classes  FWI  Region
# ...

# %%
df.drop(columns='index',inplace=True)

# %%
df
# Out:
#     month day  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI   BUI  \
# 0      06  01  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1      06  02  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2      06  03  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3      06  04  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4      06  05  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..    ...  ..   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 237    09  26  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 238    09  27  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 239    09  28  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 240    09  29  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 241    09  30  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#           Classes  FWI  Region
# 0     not fire     0.5       0
# ...

# %%
df.iloc[0].drop(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.iloc[0].drop(inplace=True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:5237, in Series.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5140 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5141 def drop(  # type: ignore[override]
#    5142     self,
#    (...)
# ...

# %%
df.iloc[[0]].drop(inplace = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.iloc[[0]].drop(inplace = True)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:5396, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5248 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5249 def drop(  # type: ignore[override]
#    5250     self,
#    (...)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  Classes      243 non-null    object
#  13  FWI          243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0  01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4
# 1  02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9
# 2  03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3  04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7
# 4  05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9
#
#        Classes  FWI  Region
# 0  not fire     0.5       0
# 1  not fire     0.4       0
# 2  not fire     0.1       0
# 3  not fire       0       0
# 4  not fire     0.5       0

# %%
df['day']=df['day'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 df['day']=df['day'].astype(int)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/internals/managers.py:450, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df[['month','day','year','Temperature','RH','Ws']]=df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          241 non-null    int64
#  1   month        241 non-null    int64
#  2   year         241 non-null    int64
#  3   Temperature  241 non-null    int64
#  4   RH           241 non-null    int64
#  5   Ws           241 non-null    int64
#  6   Rain         241 non-null    object
#  7   FFMC         241 non-null    object
#  8   DMC          241 non-null    object
#  9   DC           241 non-null    object
#  10  ISI          241 non-null    object
#  11  BUI          241 non-null    object
#  12  Classes      241 non-null    object
#  13  FWI          241 non-null    object
#  14  Region       241 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.4+ KB

# %%
objects = [features for features in df.columns if df[features].dtypes=='O']

# %%
objects
# Out:
# ['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'Classes', 'FWI']

# %%
for i in objects :
    if i!= 'Classes':
        df[i]=df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        242 non-null    int64
#  1   day          242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  Classes      242 non-null    object
#  13  FWI          242 non-null    float64
#  14  Region       242 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.5+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  241.000000  241.000000   241.0   241.000000  241.000000  241.000000
# mean    15.763485    7.502075  2012.0    32.182573   61.937759   15.514523
# std      8.780072    1.111022     0.0     3.613612   14.842516    2.812323
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.000000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  241.000000  241.000000  241.000000  241.000000  241.000000  241.000000
# mean     0.760581   78.064730   14.784232   49.775934    4.778423   16.807469
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          241 non-null    int64
#  1   month        241 non-null    int64
#  2   year         241 non-null    int64
#  3   Temperature  241 non-null    int64
#  4   RH           241 non-null    int64
#  5   Ws           241 non-null    int64
#  6   Rain         241 non-null    float64
#  7   FFMC         241 non-null    float64
#  8   DMC          241 non-null    float64
#  9   DC           241 non-null    float64
#  10  ISI          241 non-null    float64
#  11  BUI          241 non-null    float64
#  12  Classes      241 non-null    object
#  13  FWI          241 non-null    float64
#  14  Region       241 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.4+ KB

# %%
## Let ave the cleaned dataset
df.to_csv('cleaned_dataset_Algerian_forest_fires.csv',index=False)

# %% [markdown]
# Exploratary Data Analysis

# %%
df_copy = df.drop(['day','month','year'],axis=1)

# %%
df_copy.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI      Classes  FWI  \
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  not fire     0.5
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  not fire     0.4
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  not fire     0.1
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  not fire     0.0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  not fire     0.5
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         100
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  FWI  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4        0  0.5
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9        0  0.4
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7        0  0.1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7        0  0.0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9        0  0.5
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...      ...  ...
# 237           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9        1  6.5
# 238           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2        0  0.0
# 239           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4        0  0.2
# 240           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1        0  0.7
# 241           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8        0  0.5
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df['Classes'].value_counts()
# Out:
# fire             131
# not fire         100
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
## Plot desnity plot for all features
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
plt.show()
# Out:
# /tmp/ipykernel_77/1497677876.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
## plot desnity plot for all features
plt.style.use('seaborn')
df_copy.hist(bins=50,figsize=(20,15))
# Out:
# /tmp/ipykernel_77/3971081512.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# array([[<AxesSubplot: title={'center': 'Temperature'}>,
#         <AxesSubplot: title={'center': 'RH'}>,
#         <AxesSubplot: title={'center': 'Ws'}>],
#        [<AxesSubplot: title={'center': 'Rain'}>,
#         <AxesSubplot: title={'center': 'FFMC'}>,
#         <AxesSubplot: title={'center': 'DMC'}>],
#        [<AxesSubplot: title={'center': 'DC'}>,
#         <AxesSubplot: title={'center': 'ISI'}>,
#         <AxesSubplot: title={'center': 'BUI'}>],
#        [<AxesSubplot: title={'center': 'Classes'}>,
#         <AxesSubplot: title={'center': 'FWI'}>,
#         <AxesSubplot: title={'center': 'Region'}>]], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   month        242 non-null    int64
#  1   day          242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  Classes      242 non-null    object
#  13  FWI          242 non-null    float64
#  14  Region       242 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.5+ KB

# %%
df.head()
# Out:
#    month  day  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      6    1  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      6    2  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      6    3  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      6    4  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      6    5  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#        Classes  FWI  Region
# 0  not fire     0.5       0
# 1  not fire     0.4       0
# 2  not fire     0.1       0
# 3  not fire     0.0       0
# 4  not fire     0.5       0

# %%
## Percentage for Pie Chart

percentage= df_copy['Classes'].value_counts(normalize=True)*100

# %%
percentage
# Out:
# 1    56.61157
# 0    43.38843
# Name: Classes, dtype: float64

# %%
#plotting piechart
classlabels=['Fire','Not Fire']
plt.figure(figsize=(12,7))
plt.pieI(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title('Pie Chart of Classes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 4
#       2 classlabels=['Fire','Not Fire']
#       3 plt.figure(figsize=(12,7))
# ----> 4 plt.pieI(percentage,labels=classlabels,autopct='%1.1f%%')
#       5 plt.title('Pie Chart of Classes')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'pieI'

# %%
# plotting piechart
classlabels=["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(percentage,labels=classlabels,autopct='%1.1f%%')
plt.title("Pie Chart of Classes")
plt.show()

# %%
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.649404 -0.291385 -0.326603  0.670543  0.482212
# RH             -0.649404  1.000000  0.247160  0.221515 -0.643212 -0.405784
# Ws             -0.291385  0.247160  1.000000  0.172344 -0.173592 -0.003003
# Rain           -0.326603  0.221515  0.172344  1.000000 -0.546977 -0.288109
# FFMC            0.670543 -0.643212 -0.173592 -0.546977  1.000000  0.601704
# DMC             0.482212 -0.405784 -0.003003 -0.288109  0.601704  1.000000
# DC              0.372699 -0.223910  0.077365 -0.297402  0.505368  0.875498
# ISI             0.601275 -0.685130  0.006140 -0.346975  0.739520  0.678958
# BUI             0.456215 -0.350933  0.029303 -0.299216  0.590144  0.982173
# Classes         0.512241 -0.429272 -0.072702 -0.378692  0.769157  0.583649
# FWI             0.564627 -0.579230  0.030385 -0.323844  0.691065  0.875385
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# /tmp/ipykernel_77/4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <AxesSubplot: >

# %%
## Box Plots
sns.boxplot(df['FWI'],color='green')
# Out:
# <AxesSubplot: >

# %%
df.head()
# Out:
#    month  day  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0      6    1  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1      6    2  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2      6    3  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3      6    4  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4      6    5  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#        Classes  FWI  Region
# 0  not fire     0.5       0
# 1  not fire     0.4       0
# 2  not fire     0.1       0
# 3  not fire     0.0       0
# 4  not fire     0.5       0

# %%
df['Classes']=np.where(df['Classes'].str.contains('not fire'),'not fire','fire')

# %%
## Monthly Fire Analysis
dftemp=df.loc[df['Region']==1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Sidi- Bel Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Sidi- Bel Regions')

# %%
## Monthly Fire Analysis
dftemp=df.loc[df['Region']==0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data=df)
plt.ylabel('Number of Fires',weight='bold')
plt.xlabel('Months',weight='bold')
plt.title("Fire Analysis of Brjaia Regions",weight='bold')
# Out:
# Text(0.5, 1.0, 'Fire Analysis of Brjaia Regions')

# %%
df
# Out:
#      month  day  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0        6    1  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1        6    2  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2        6    3  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3        6    4  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4        6    5  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..     ...  ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 237      9   26  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 238      9   27  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 239      9   28  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 240      9   29  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 241      9   30  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#       Classes  FWI  Region
# ...
