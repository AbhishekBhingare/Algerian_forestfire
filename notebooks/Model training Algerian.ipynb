# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cleaned_dataset_Algerian_forest_fires.csv')

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 237   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 238   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 239   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 240   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 241   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#           Classes  FWI  Region
# 0     not fire     0.5       0
# 1     not fire     0.4       0
# 2     not fire     0.1       0
# 3     not fire     0.0       0
# 4     not fire     0.5       0
# ..            ...  ...     ...
# 237       fire     6.5       1
# 238   not fire     0.0       1
# 239   not fire     0.2       1
# 240   not fire     0.7       1
# 241  not fire      0.5       1
#
# [242 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          242 non-null    int64
#  1   month        242 non-null    int64
#  2   year         242 non-null    int64
#  3   Temperature  242 non-null    int64
#  4   RH           242 non-null    int64
#  5   Ws           242 non-null    int64
#  6   Rain         242 non-null    float64
#  7   FFMC         242 non-null    float64
#  8   DMC          242 non-null    float64
#  9   DC           242 non-null    float64
#  10  ISI          242 non-null    float64
#  11  BUI          242 non-null    float64
#  12  Classes      242 non-null    object
#  13  FWI          242 non-null    float64
#  14  Region       242 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.5+ KB

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  242.000000  242.000000   242.0   242.000000  242.000000  242.000000
# mean    15.702479    7.495868  2012.0    32.181818   61.975207   15.500000
# std      8.813084    1.112912     0.0     3.606127   14.823141    2.815561
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.250000   14.000000
# 50%     16.000000    7.500000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.000000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  242.000000  242.000000  242.000000  242.000000  242.000000  242.000000
# mean     0.760331   77.978099   14.733471   49.604132    4.761157   16.749587
# std      2.006937   14.222254   12.391293   47.687649    4.152505   14.228040
# min      0.000000   28.600000    0.700000    6.900000    0.000000    1.100000
# 25%      0.000000   72.375000    5.800000   14.325000    1.400000    6.025000
# 50%      0.000000   83.500000   11.300000   33.250000    3.500000   12.450000
# 75%      0.500000   88.300000   20.850000   70.050000    7.275000   22.775000
# max     16.800000   96.000000   65.900000  220.400000   19.000000   68.000000
#
#               FWI      Region
# count  242.000000  242.000000
# mean     7.064050    0.500000
# std      7.442537    0.501036
# min      0.000000    0.000000
# 25%      0.725000    0.000000
# 50%      4.450000    0.500000
# 75%     11.525000    1.000000
# max     31.100000    1.000000

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'Classes', 'FWI', 'Region'],
#       dtype='object')

# %%
df.drop(['day','month','year'], axis=1,inplace=True)

# %%
df
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI       Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4   not fire
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9   not fire
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7   not fire
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7   not fire
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9   not fire
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...           ...
# 237           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9       fire
# 238           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2   not fire
# 239           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4   not fire
# 240           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1   not fire
# 241           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  not fire
#
#      FWI  Region
# 0    0.5       0
# 1    0.4       0
# 2    0.1       0
# 3    0.0       0
# 4    0.5       0
# ..   ...     ...
# 237  6.5       1
# 238  0.0       1
# 239  0.2       1
# 240  0.7       1
# 241  0.5       1
#
# [242 rows x 12 columns]

# %%
df.Classes.value_counts()
# Out:
# fire             131
# not fire         100
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  FWI  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0  0.5       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0  0.4       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0  0.1       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0  0.0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0  0.5       0

# %%
df['Classes'].value_counts()
# Out:
# 1    137
# 0    105
# Name: Classes, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242 entries, 0 to 241
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  242 non-null    int64
#  1   RH           242 non-null    int64
#  2   Ws           242 non-null    int64
#  3   Rain         242 non-null    float64
#  4   FFMC         242 non-null    float64
#  5   DMC          242 non-null    float64
#  6   DC           242 non-null    float64
#  7   ISI          242 non-null    float64
#  8   BUI          242 non-null    float64
#  9   Classes      242 non-null    int64
#  10  FWI          242 non-null    float64
#  11  Region       242 non-null    int64
# dtypes: float64(7), int64(5)
# memory usage: 22.8 KB

# %%
# independent and dependent features
x = df.drop('FWI', axis=1)
y = df['FWI']

# %%
x.head()
# Out:
#    Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  Classes  Region
# 0           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4        0       0
# 1           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9        0       0
# 2           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7        0       0
# 3           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7        0       0
# 4           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9        0       0

# %%
y.head()
# Out:
# 0    0.5
# 1    0.4
# 2    0.1
# 3    0.0
# 4    0.5
# Name: FWI, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25  , random_state= 42)

# %%
x_train.shape, x_test.shape
# Out:
# ((181, 11), (61, 11))

# %%
y_train.shape, y_test.shape
# Out:
# ((181,), (61,))

# %%
#feature selection based on correlation
x_train.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.647510 -0.309373 -0.330127  0.692711  0.488885
# RH             -0.647510  1.000000  0.265303  0.233712 -0.632600 -0.412118
# Ws             -0.309373  0.265303  1.000000  0.220124 -0.169547  0.003935
# Rain           -0.330127  0.233712  0.220124  1.000000 -0.547384 -0.285149
# FFMC            0.692711 -0.632600 -0.169547 -0.547384  1.000000  0.621637
# DMC             0.488885 -0.412118  0.003935 -0.285149  0.621637  1.000000
# DC              0.372255 -0.244351  0.108079 -0.298772  0.538369  0.876716
# ISI             0.613147 -0.692688  0.008882 -0.345042  0.752709  0.693169
# BUI             0.460917 -0.362299  0.042263 -0.296243  0.611299  0.983693
# Classes         0.519674 -0.433190 -0.055013 -0.384426  0.782470  0.613382
# Region          0.241418 -0.356014 -0.244356 -0.063891  0.204315  0.185937
#
#                    DC       ISI       BUI   Classes    Region
# Temperature  0.372255  0.613147  0.460917  0.519674  0.241418
# RH          -0.244351 -0.692688 -0.362299 -0.433190 -0.356014
# Ws           0.108079  0.008882  0.042263 -0.055013 -0.244356
# Rain        -0.298772 -0.345042 -0.296243 -0.384426 -0.063891
# FFMC         0.538369  0.752709  0.611299  0.782470  0.204315
# DMC          0.876716  0.693169  0.983693  0.613382  0.185937
# DC           1.000000  0.548789  0.946989  0.546378 -0.090875
# ISI          0.548789  1.000000  0.659374  0.749556  0.255222
# BUI          0.946989  0.659374  1.000000  0.609634  0.085926
# Classes      0.546378  0.749556  0.609634  1.000000  0.149958
# Region      -0.090875  0.255222  0.085926  0.149958  1.000000

# %% [markdown]
# feature selection

# %%
plt.figure(figsize=(12,10))
corr = x_train.corr()
sns.heatmap(corr,annot = True)
# Out:
# <AxesSubplot: >

# %%
def correlation(dataset, threshold) :
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold :
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr
# Out:
#   Cell In[31], line 2
#
#     ^
# SyntaxError: incomplete input

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: 
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold--Domain expertise
corr_features=correlation(x_train,0.85)

# %%
corr_features
# Out:
# {'BUI', 'DC'}

# %%
x_train.drop(corr_features,axis=1,inplace = True)
x_test.drop(corr_features, axis=1, inplace = True)
x_train.shape, x_test.shape
# Out:
# ((181, 9), (61, 9))

# %% [markdown]
# feature selection and standardization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[-0.84718031,  0.75720545,  1.27359309, ..., -0.60743201,
#         -1.07459849, -0.99449032],
#        [-0.03871123, -0.52178745, -0.51616117, ...,  0.08076368,
#          0.93058013,  1.00554021],
#        [-0.84718031, -1.46420327, -2.66386629, ..., -0.46504669,
#          0.93058013,  1.00554021],
#        ...,
#        [-1.92513908,  0.89183628,  0.55769138, ..., -1.05831884,
#         -1.07459849, -0.99449032],
#        [ 1.03924755, -0.45447203,  0.19974053, ...,  0.84015202,
#          0.93058013,  1.00554021],
#        [-0.57769061,  0.9591517 ,  1.9894948 , ..., -0.84474086,
#         -1.07459849, -0.99449032]])

# %% [markdown]
# ## Box Plots To understand Effect Of Standard Scaler

# %%
plt.subplots(figsize=(15, 5))
plt.subplot(1, 2, 1)
sns.boxplot(data=x_train)
plt.title('x_train Before Scaling')
plt.subplot(1, 2, 2)
sns.boxplot(data=x_train_scaled)
plt.title('x_train After Scaling')
# Out:
# /tmp/ipykernel_900/2892966994.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1, 2, 1)
# Text(0.5, 1.0, 'x_train After Scaling')

# %% [markdown]
# Linear regreassion model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linreg=LinearRegression()
linreg.fit(x_train_scaled,y_train)
y_pred=linreg.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.5837131463619636
# R2 Score 0.9834414954962315

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lasso=Lasso()
lasso.fit(x_train_scaled,y_train)
y_pred=lasso.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 1.1439969561092533
# R2 Score 0.9498970288705136

# %% [markdown]
# ## Ridge Regression model

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
ridge=Ridge()
ridge.fit(x_train_scaled,y_train)
y_pred=ridge.predict(x_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 0.6123074618355627
# R2 Score 0.9826082263318291

# %% [markdown]
# ## Elasticnet Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
elastic=ElasticNet()
elastic.fit(x_train_scaled,y_train)
y_pred=elastic.predict(X_test_scaled)
mae=mean_absolute_error(y_test,y_pred)
score=r2_score(y_test,y_pred)
print("Mean absolute error", mae)
print("R2 Score", score)
# Out:
# Mean absolute error 1.890760446719498
# R2 Score 0.8732832242877046

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))

# %%
import pickle
pickle.dump(scaler,open('scaler.pkl','wb'))
pickle.dump(ridge,open('ridge.pkl','wb'))
